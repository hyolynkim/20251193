# %% [markdown]
# # GRAPH

# %% [markdown]
# 5. 모든 정점이 연결된 완전 그래프에서는 배열의 모든 칸이 유효한 간선 정보로 채워지므로 인접 행렬의 공간 낭비가 전혀 발생하지 않습니다. 오히려 인접 리스트를 사용하면 모든 간선에 대해 추가적인 포인터(주소 값) 메모리가 소모되므로 인접 행렬이 훨씬 더 메모리 효율적입니다.

# %% [markdown]
# 6. 간선이 드문 희소 그래프에서는 인접 행렬을 쓰면 빈 공간(0)이 대부분을 차지해 심각한 메모리 낭비가 발생하므로, 존재하는 간선만 노드로 연결하는 인접 리스트가 훨씬 효율적입니다. 또한 인접 리스트는 특정 정점과 연결된 이웃 정점들을 탐색할 때 2차원 배열 전체를 돌 필요 없이 실제 간선 수만큼만 탐색하므로 시간 복잡도 측면에서도 매우 유리합니다.

# %% [markdown]
# 8. DFS(1)의 인접 노드는 2와 4인데, x=2일 때 DFS(2)를 호출하고 그 재귀 과정에서 4번 노드가 이미 방문됩니다. 따라서 DFS(1)이 직접 DFS(x)를 호출한 횟수는 1번입니다.

# %% [markdown]
# 12-(1) 프림알고리즘
#
# ![image.png](attachment:05bd9843-f5c8-45cc-961a-061b8737b569.png)

# %% [markdown]
# 12-(2) 크루스칼 알고리즘
# ![image.png](attachment:b4d95947-1bd2-47d9-ba32-e6cdcba6f1be.png)

# %% [markdown]
# 16
# -STACK을 이용한 위상정렬 코드
# TopologicalSort_Stack():
#     진입차수가 0인 모든 노드를 STACK에 push
#     while STACK is not empty:
#         v = STACK.pop()
#         v를 결과 리스트에 추가
#         for each w in v.adj:
#             w의 진입차수 -= 1
#             if w의 진입차수 == 0:
#                 STACK.push(w)
# 정답: 시작점 a가 고정된 상태에서, 순서가 고정된 뼈대인 d → e → f 사이사이의 빈틈에 b가 c보다 앞에 오도록 두 정점을 끼워 넣는 방법이 총 12가지 존재합니다. 그리고 이 모든 경우마다 e와 f가 끝난 시점(맨 뒤)에서 선후 관계가 없는 g와 h가 서로 위치를 바꾸는 방법이 2가지씩 존재하므로, 최종적으로 이 두 독립적인 조합을 곱한 24가지($12 \times 2$)의 위상 정렬 경로가 만들어집니다.

# %% [markdown]
# 17. 다익스트라 알고리즘
# ![image.png](attachment:3a30639f-ad04-4999-9307-93275b0576d7.png)

# %% [markdown]
# 18. 음의 가중치가 존재하면 먼저 방문하여 최단 거리를 확정 지은 정점의 최소 비용이 나중에 다른 정점을 거쳐 오면서 더 작게 갱신되는 반전이 발생할 수 있습니다.정점 $A, B, C$가 있고 간선이 $A \rightarrow B(5), A \rightarrow C(2), C \rightarrow B(-4)$로 구성된 그래프에서 다익스트라는 가장 가까운 $C(2)$와 $B(5)$를 차례로 방문하며 최단 거리를 확정합니다.하지만 실제 $B$의 최단 거리는 $A \rightarrow C \rightarrow B$를 거친 $-2$가 되므로, 이미 가중치가 양수일 것이라 가정하고 탐색을 끝낸 정점들의 최단 거리가 도미노처럼 깨지게 됩니다.이처럼 한 번 $S$ 집합에 들어가 탐색이 완료된 정점은 절대 다시 의심하지 않고 넘어가 버리는 다익스트라의 탐욕적(Greedy) 특성 때문에 음의 가중치가 있는 그래프에서는 알고리즘이 올바르게 작동하지 않습니다.

# %% [markdown]
# 22. 음의 사이클이 그래프에 존재하는 경우에 벨만-포드 알고리즘이 실행될 수 없다.

# %% [markdown]
# # SORTING

# %% [markdown]
# 5-(1) 선택 정렬
# ![image.png](attachment:62230ee4-9ab3-4901-bac2-a1a6ce3b6d89.png)

# %% [markdown]
# 5-(2) 버블정렬
# ![image.png](attachment:e87cf2cd-c6ce-4506-8b06-8ffb0750ff2a.png)

# %% [markdown]
# 5-(3) 삽입정렬
# ![image.png](attachment:523d4630-97e3-4aed-af23-d0ad2c195c6b.png)

# %% [markdown]
# 6-(1) 병합정렬
# ![image.png](attachment:12ed050d-0cc1-45e7-a4df-bdbbd0e94ad2.png)

# %% [markdown]
# 6-(2) 힙 정렬
# ![image.png](attachment:2c6da247-14b1-4d92-9e56-fd1180ccadd3.png)

# %% [markdown]
# 6-(3) 퀵 정렬
# ![image.png](attachment:32c1ba4f-0ef9-45d3-8c00-50b20bee17cd.png)
